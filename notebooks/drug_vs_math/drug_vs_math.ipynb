# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('..\..\data_sets\lsd_math_score_data.csv')

# %%
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
time  = data[["Time_Delay_in_Minutes"]]
score = data[["Avg_Math_Test_Score"]]
lsd   = data[["LSD_ppm"]]

# %%
plt.figure(figsize=(4,3))
plt.plot(time, lsd, color = 'g')
plt.title('time_vs_lsd')
plt.xlabel('time')
plt.ylabel('lsd')
plt.ylim(1,7)
plt.xlim(1,500)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(time, score,color = 'r')
plt.title('time_vs_score')
plt.xlabel('time')
plt.ylabel('score')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(lsd, score,color = 'r')
plt.title('lsd_vs_score')
plt.xlabel('lsd')
plt.ylabel('score')
plt.show()

# %%
regression = LinearRegression()

regression.fit(lsd, score)
# Out:
# LinearRegression()

# %%
regression.score(lsd, score)
# Out:
# 0.8778349707775888

# %%
#the intercept of the line > 0
c = regression.intercept_

# %%
#the slope of the line 01
m = regression.coef_

# %%
val = 4.2
y_pred = m*val + c
print(y_pred) 
#or
print(regression.predict(lsd))
# Out:
# [[51.28411482]]
# [[78.58279806]
#  [62.36575851]
#  [59.75301325]
#  [46.86947628]
#  [36.59868457]
#  [35.06707528]
#  [31.37319405]]

# %%
plt.figure(figsize=(4,3))
plt.scatter(lsd, score , color = 'g')
plt.plot(lsd, regression.predict(lsd), color = 'b')
plt.title('time_vs_lsd')
plt.xlabel('time')
plt.ylabel('lsd')
plt.show()
